# %% [markdown]
# # IBM Academy: Advanced AI - Studi Independen Batch 6 Infinite Learning
# ## Team 3 - Personal Mentor (Siska Anggraeni)
# ### Anggota:
# ### 1. Budi Cahyono
# ### 2. Imam Zaki Nursyamsi
# ### 3. Vander Mulya Putra

# %% [markdown]
# # 1. Importing Libraries
# Library-library apa saja yang dibutuhkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Loading the Dataset

# %%
# Source: https://www.kaggle.com/code/chirag9073/airbnb-analysis-visualization-and-prediction
# New York City Airbnb Open Data - Airbnb listings and metrics in NYC, NY, USA (2019)
airbnb = pd.read_csv("/content/AB_NYC_2019.csv")

# %% [markdown]
# Print the Shape of the dataset

# %%
airbnb.shape
# Out:
# (48895, 16)

# %% [markdown]
# Print the Datatypes of the dataset

# %%
airbnb.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# # 3. Data Cleaning

# %% [markdown]
# Removing the Duplicates (jika ada)

# %%
airbnb.duplicated().sum()
airbnb.drop_duplicates(inplace=True)

# %% [markdown]
# Check for the null values in each column

# %%
airbnb.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# Drop unnecessary columns

# %%
airbnb.drop(['name','id','host_name','last_review'], axis=1, inplace=True)

# %% [markdown]
# Examining Changes (Melihat perubahan)

# %%
airbnb.head(10)
# Out:
#    host_id neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     2787            Brooklyn          Kensington  40.64749  -73.97237
# 1     2845           Manhattan             Midtown  40.75362  -73.98377
# 2     4632           Manhattan              Harlem  40.80902  -73.94190
# 3     4869            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4     7192           Manhattan         East Harlem  40.79851  -73.94399
# 5     7322           Manhattan         Murray Hill  40.74767  -73.97500
# 6     7356            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7     8967           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8     7490           Manhattan     Upper West Side  40.80178  -73.96723
# 9     7549           Manhattan           Chinatown  40.71344  -73.99037
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# ...

# %% [markdown]
# Replace the 'reviews per month' menjadi zero (0)

# %%
airbnb.fillna({'reviews_per_month':0}, inplace=True)

# Examing Changes
airbnb.reviews_per_month.isnull().sum()
# Out:
# 0

# %% [markdown]
# Remove the NaN values from the dataset

# %%
airbnb.isnull().sum()
airbnb.dropna(how='any',inplace=True)
airbnb.info() #.info() function is used to get a concise summary of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   host_id                         48895 non-null  int64
#  1   neighbourhood_group             48895 non-null  object
#  2   neighbourhood                   48895 non-null  object
#  3   latitude                        48895 non-null  float64
#  4   longitude                       48895 non-null  float64
#  5   room_type                       48895 non-null  object
#  6   price                           48895 non-null  int64
#  7   minimum_nights                  48895 non-null  int64
#  8   number_of_reviews               48895 non-null  int64
#  9   reviews_per_month               48895 non-null  float64
#  10  calculated_host_listings_count  48895 non-null  int64
#  11  availability_365                48895 non-null  int64
# ...

# %% [markdown]
# Examine Continous Variables

# %%
airbnb.describe()
# Out:
#             host_id      latitude     longitude         price  minimum_nights  \
# count  4.889500e+04  48895.000000  48895.000000  48895.000000    48895.000000
# mean   6.762001e+07     40.728949    -73.952170    152.720687        7.029962
# std    7.861097e+07      0.054530      0.046157    240.154170       20.510550
# min    2.438000e+03     40.499790    -74.244420      0.000000        1.000000
# 25%    7.822033e+06     40.690100    -73.983070     69.000000        1.000000
# 50%    3.079382e+07     40.723070    -73.955680    106.000000        3.000000
# 75%    1.074344e+08     40.763115    -73.936275    175.000000        5.000000
# max    2.743213e+08     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       48895.000000                    48895.000000
# mean           23.274466           1.090910                        7.143982
# ...

# %% [markdown]
# Print all the columns names

# %%
airbnb.columns
# Out:
# Index(['host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %% [markdown]
# Get Correlation between different variables
# (Mendapatkan korelasi antara variabel-variabel yang berbeda)

# %%
corr = airbnb.corr(method='kendall')
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)
airbnb.columns
# Out:
# Index(['host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
airbnb.shape
# Out:
# (48895, 12)

# %%
airbnb.head(15)
# Out:
#     host_id neighbourhood_group       neighbourhood  latitude  longitude  \
# 0      2787            Brooklyn          Kensington  40.64749  -73.97237
# 1      2845           Manhattan             Midtown  40.75362  -73.98377
# 2      4632           Manhattan              Harlem  40.80902  -73.94190
# 3      4869            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4      7192           Manhattan         East Harlem  40.79851  -73.94399
# 5      7322           Manhattan         Murray Hill  40.74767  -73.97500
# 6      7356            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7      8967           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8      7490           Manhattan     Upper West Side  40.80178  -73.96723
# 9      7549           Manhattan           Chinatown  40.71344  -73.99037
# 10     7702           Manhattan     Upper West Side  40.80316  -73.96545
# 11     7989           Manhattan      Hell's Kitchen  40.76076  -73.98867
# ...

# %% [markdown]
# # 4. Data Visualization

# %%
import seaborn as sns

# %%
airbnb['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %% [markdown]
# Plot all 'Neighbourhood Group'

# %%
sns.countplot(airbnb['neighbourhood_group'], palette="plasma")
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Neighbourhood Group')
# Out:
# Text(0.5, 1.0, 'Neighbourhood Group')

# %% [markdown]
# Plot all 'Neighbourhood'

# %%
sns.countplot(airbnb['neighbourhood'], palette="plasma")
fig = plt.gcf()
fig.set_size_inches(25,6)
plt.title('Neighbourhood')
# Out:
# Text(0.5, 1.0, 'Neighbourhood')

# %% [markdown]
# Plot all 'Room Type'

# %%
#Restaurants delivering Online or not
sns.countplot(airbnb['room_type'], palette="plasma")
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Restaurants delivering online or Not')
# Out:
# Text(0.5, 1.0, 'Restaurants delivering online or Not')

# %% [markdown]
# Relation between neighbour group and Availability of Room
# (Relasi antara neighbour group dan Availability of Room)

# %%
plt.figure(figsize=(5,5))
ax = sns.boxplot(data=airbnb, x='neighbourhood_group',y='availability_365',palette='plasma')

# %% [markdown]
# Map of Neighbourhood group (Peta sebaran Neighbourhood group)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=airbnb, x='longitude', y='latitude', hue='neighbourhood_group')
plt.ioff()

# %% [markdown]
# Map of Neighbourhood (Peta sebaran Neighbourhood)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=airbnb, x='longitude', y='latitude', hue='neighbourhood')
plt.ioff()

# %% [markdown]
# Map of Room Type (Peta sebaran Room Type)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=airbnb, x='longitude', y='latitude', hue='room_type')
plt.ioff()

# %% [markdown]
# Map of Availability of Room (Peta sebaran Availability of Room)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=airbnb, x='longitude', y='latitude', hue='availability_365')
plt.ioff()

# %% [markdown]
# # 5. Word Cloud

# %%
from wordcloud import WordCloud

# %%
plt.subplots(figsize=(25,15))

wordcloud = WordCloud(background_color='white', width=1920, height=1080).generate(" ".join(airbnb.neighbourhood))

plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('neighbourhood.png')
plt.show()

# %% [markdown]
# # 6. Regression Analysis

# %% [markdown]
# Drop Columns

# %%
airbnb.drop(['host_id','latitude','longitude','neighbourhood','number_of_reviews','reviews_per_month'], axis=1, inplace=True)

#examing the changes
airbnb.head(5)
# Out:
#   neighbourhood_group        room_type  price  minimum_nights  \
# 0            Brooklyn     Private room    149               1
# 1           Manhattan  Entire home/apt    225               1
# 2           Manhattan     Private room    150               3
# 3            Brooklyn  Entire home/apt     89               1
# 4           Manhattan  Entire home/apt     80              10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %% [markdown]
# Proses Encoding

# %%
#Encode the input Variables
def Encode(airbnb):
    for column in airbnb.columns[airbnb.columns.isin(['neighbourhood_group', 'room_type'])]:
        airbnb[column] = airbnb[column].factorize()[0]
    return airbnb

airbnb_en = Encode(airbnb.copy())

# %% [markdown]
# Mengamati Perubahan pada Dataset

# %%
airbnb_en.head(15)
# Out:
#     neighbourhood_group  room_type  price  minimum_nights  \
# 0                     0          0    149               1
# 1                     1          1    225               1
# 2                     1          0    150               3
# 3                     0          1     89               1
# 4                     1          1     80              10
# 5                     1          1    200               3
# 6                     0          0     60              45
# 7                     1          0     79               2
# 8                     1          0     79               2
# 9                     1          1    150               1
# 10                    1          1    135               5
# 11                    1          0     85               2
# 12                    0          0     89               4
# 13                    1          0     85               2
# 14                    1          1    120              90
#
# ...

# %% [markdown]
# Mendapatkan korelasi antara variabel-variabel yang berbeda

# %%
#Get Correlation between different variables
corr = airbnb_en.corr(method='kendall')
plt.figure(figsize=(18,12))
sns.heatmap(corr, annot=True)
airbnb_en.columns
# Out:
# Index(['neighbourhood_group', 'room_type', 'price', 'minimum_nights',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %% [markdown]
# Importing Libraries for Regression Analysis

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score

# %% [markdown]
# Test and Training the Data

# %%
# Defining the independent variables and dependent variables
x = airbnb_en.iloc[:,[0,1,3,4,5]]
y = airbnb_en['price']

# Getting Test and Training Set
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=353)
x_train.head()
y_train.head()
# Out:
# 17736    125
# 24351    101
# 10069    189
# 11679    145
# 16315    120
# Name: price, dtype: int64

# %%
x_train.shape
# Out:
# (44005, 5)

# %% [markdown]
# 1. LINEAR REGRESSION MODEL

# %%
# Prepare a Linear Regression Model
reg=LinearRegression()
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.07480306392848757

# %% [markdown]
# 2. DECISION TREE REGRESSION MODEL

# %%
# Preparing a Decision Tree Regression
from sklearn.tree import DecisionTreeRegressor

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=105)
DTree=DecisionTreeRegressor(min_samples_leaf=.0001)
DTree.fit(x_train,y_train)
y_predict=DTree.predict(x_test)

from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 0.2534153986765417

# %% [markdown]
# 3. RANDOM FOREST REGRESSION MODEL

# %%
# Preparing a Random Forest Regression
from sklearn.ensemble import RandomForestRegressor  # Import RandomForestRegressor

# Splitting the data into training and testing sets
from sklearn.model_selection import train_test_split

# Assuming x and y are already defined

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=105)

# Initializing Random Forest Regressor with some parameters
# You can adjust these parameters according to your needs
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=105)

# Fitting the model
rf_regressor.fit(x_train, y_train)

# Making predictions
y_predict = rf_regressor.predict(x_test)

# Calculating R^2 score
from sklearn.metrics import r2_score
r2_score(y_test, y_predict)
# Out:
# 0.2397327929670413

# %% [markdown]
# Thank You!
